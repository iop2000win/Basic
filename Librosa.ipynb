# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['axes.unicode_minus'] = False

import librosa

# %%
src_path = './common_voice_en_16231.wav'

# %%
# y : 음원의 파형 데이터
# sr(samplig rate) : 주파수 분석 및 파형의 시간 간격을 결정
y, sr = librosa.load(src_path)

# %%
print(y, len(y))
print(sr)
# Out:
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  1.3101535e-05
#  -4.9140868e-07  0.0000000e+00] 153998
# 22050

# %%
fig, ax = plt.subplots(1, 1, figsize = (16, 10))

ax.plot(y,
        color = 'g',
        alpha = 0.5)

ax.grid()

# %%
# librosa.feature.melspectrogram
# librosa.power_to_db
